# %% [markdown]
# # PPO (Stable-Baselines3) — LunarLander-v2 (Improved)
#
# Same experiment as the hand-written PPO notebook, now powered by **Stable-Baselines3**.
# All outputs (episode reward plot, steps plot, loss plot, entropy plot, video, evaluation)
# are identical in structure so results can be directly compared.
#
# **Improvements over previous run:**
# - `NUM_ENVS = 16` (was 8) — more parallel envs for faster diverse data collection
# - `TOTAL_TIMESTEPS = 2_000_000` (was 1_000_000) — reward was still climbing, needed more time
# - `ENTROPY_COEF = 0.02` (was 0.01) — prevents early policy collapse seen in entropy plot
# - `LRSchedulerCallback` — decays LR from 1e-4 → 1e-5 linearly, stabilises late training
#
# Install if needed:
# ```
# pip install stable-baselines3[extra]
# ```

# %%
# Imports
import gymnasium as gym
import numpy as np
import torch
import matplotlib.pyplot as plt
import glob
from collections import deque
from IPython.display import Video, display

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.vec_env import VecVideoRecorder

VERSION       = 'ppo_v2'   # used to namespace all output files
SEED = 42
np.random.seed(SEED)
torch.manual_seed(SEED)

print(f'SB3 version: {__import__("stable_baselines3").__version__}')
print(f'PyTorch:     {torch.__version__}')
print(f'Device:      {"cuda" if torch.cuda.is_available() else "cpu"}')
# Out:
# SB3 version: 2.3.2
# PyTorch:     2.0.1+cu118
# Device:      cuda

# %%
# ── Config — mirrors the hand-written PPO notebook exactly ───────────────────
ENV_NAME      = 'LunarLander-v2'
NUM_ENVS      = 16         # improved: was 8 — more envs = more diverse data per rollout
NUM_EPISODES  = 2000       # approximate target episodes
MAX_STEPS     = 1000       # max steps per episode

# SB3 PPO hyperparameters
LEARNING_RATE    = 1e-4
LEARNING_RATE_END = 1e-5   # scheduler decays to this by end of training
GAMMA            = 0.99
GAE_LAMBDA       = 0.95
CLIP_EPS         = 0.2
VALUE_COEF       = 0.25
ENTROPY_COEF     = 0.02    # improved: was 0.01 — prevents early entropy collapse
MAX_GRAD_NORM    = 0.5
N_STEPS          = 1024    # rollout steps per env
BATCH_SIZE       = 256     # mini-batch size
N_EPOCHS         = 4       # PPO update epochs per rollout

# improved: was NUM_EPISODES*500=1M — late episodes avg 750+ steps so needed more
TOTAL_TIMESTEPS  = 2_000_000

SOLVE_REWARD  = 200
SOLVE_WINDOW  = 100

# Diagnostics
steps_per_rollout = NUM_ENVS * N_STEPS
total_updates     = TOTAL_TIMESTEPS // steps_per_rollout
print('Config set.')
print(f'Parallel envs      : {NUM_ENVS}')
print(f'Steps per rollout  : {steps_per_rollout:,}  ({NUM_ENVS} envs x {N_STEPS} steps)')
print(f'Total updates      : ~{total_updates}')
print(f'Total timesteps    : {TOTAL_TIMESTEPS:,}')
print(f'LR schedule        : {LEARNING_RATE:.0e} -> {LEARNING_RATE_END:.0e}')
# Out:
# Config set.
# Parallel envs      : 16
# Steps per rollout  : 16,384  (16 envs x 1024 steps)
# Total updates      : ~122
# Total timesteps    : 2,000,000
# LR schedule        : 1e-04 -> 1e-05

# %%
# ── Episode tracking callback ────────────────────────────────────────────────
# SB3 trains by timesteps, not episodes. This callback captures
# per-episode rewards/steps/losses so we can produce identical plots.

class EpisodeLogger(BaseCallback):
    """
    Logs per-episode reward, steps, and SB3 training losses
    so we can reproduce the same 4-panel plot as the hand-written PPO.
    """
    def __init__(self, solve_reward=SOLVE_REWARD, solve_window=SOLVE_WINDOW, verbose=0):
        super().__init__(verbose)
        self.rewards_history = []
        self.steps_history   = []
        self.loss_history    = []   # collected at each PPO update
        self.rolling         = deque(maxlen=solve_window)
        self.solve_reward    = solve_reward
        self.solve_window    = solve_window
        self.solved_at       = None
        self._ep_rewards     = None
        self._ep_steps       = None

    def _on_training_start(self):
        n = self.training_env.num_envs
        self._ep_rewards = np.zeros(n)
        self._ep_steps   = np.zeros(n, dtype=int)

    def _on_step(self) -> bool:
        rewards = self.locals['rewards']
        dones   = self.locals['dones']

        self._ep_rewards += rewards
        self._ep_steps   += 1

        for i, done in enumerate(dones):
            if done:
                ep = len(self.rewards_history) + 1
                self.rewards_history.append(self._ep_rewards[i])
                self.steps_history.append(self._ep_steps[i])
                self.rolling.append(self._ep_rewards[i])

                roll_mean = np.mean(self.rolling)
                if ep % 50 == 0:
                    print(f'Ep {ep:4d} | steps {self._ep_steps[i]:4d} | '
                          f'reward {self._ep_rewards[i]:8.2f} | '
                          f'rolling{self.solve_window} {roll_mean:7.2f}')

                if (self.solved_at is None
                        and len(self.rolling) == self.solve_window
                        and roll_mean >= self.solve_reward):
                    self.solved_at = ep
                    print(f'\n*** SOLVED at episode {ep} '
                          f'(rolling mean = {roll_mean:.2f}) ***\n')

                self._ep_rewards[i] = 0
                self._ep_steps[i]   = 0

        return True  # continue training

    def _on_rollout_end(self):
        # Grab loss values logged by SB3 into its logger
        logs = self.model.logger.name_to_value
        self.loss_history.append({
            'actor':   logs.get('train/policy_gradient_loss', 0.0),
            'critic':  logs.get('train/value_loss', 0.0),
            'entropy': logs.get('train/entropy_loss', 0.0),
            'total':   logs.get('train/loss', 0.0),
        })

print('EpisodeLogger callback defined.')


# ── LR Scheduler Callback ────────────────────────────────────────────────────
class LRSchedulerCallback(BaseCallback):
    """
    Linearly decays the learning rate from initial_lr to final_lr
    over total_timesteps. Called every step.
    """
    def __init__(self, initial_lr, final_lr, total_timesteps, verbose=0):
        super().__init__(verbose)
        self.initial_lr      = initial_lr
        self.final_lr        = final_lr
        self.total_timesteps = total_timesteps

    def _on_step(self) -> bool:
        progress = min(self.num_timesteps / self.total_timesteps, 1.0)
        new_lr   = self.initial_lr + (self.final_lr - self.initial_lr) * progress
        for pg in self.model.policy.optimizer.param_groups:
            pg['lr'] = new_lr
        return True

print('LRSchedulerCallback defined.')
# Out:
# EpisodeLogger callback defined.
# LRSchedulerCallback defined.

# %%
# ── Build vectorised environment & SB3 PPO model ────────────────────────────
vec_env = make_vec_env(ENV_NAME, n_envs=NUM_ENVS, seed=SEED)

model = PPO(
    policy          = 'MlpPolicy',
    env             = vec_env,
    learning_rate   = LEARNING_RATE,
    gamma           = GAMMA,
    gae_lambda      = GAE_LAMBDA,
    clip_range      = CLIP_EPS,
    vf_coef         = VALUE_COEF,
    ent_coef        = ENTROPY_COEF,
    max_grad_norm   = MAX_GRAD_NORM,
    n_steps         = N_STEPS,
    batch_size      = BATCH_SIZE,
    n_epochs        = N_EPOCHS,
    policy_kwargs   = dict(net_arch=[256, 256]),
    seed            = SEED,
    verbose         = 0,
)

print(model.policy)
total_params = sum(p.numel() for p in model.policy.parameters())
print(f'\nTotal parameters   : {total_params:,}')
print(f'Parallel envs      : {vec_env.num_envs}')
print(f'Steps per rollout  : {vec_env.num_envs * N_STEPS:,}')
print(f'Total updates      : ~{TOTAL_TIMESTEPS // (vec_env.num_envs * N_STEPS)}')
# Out:
# ActorCriticPolicy(
#   (features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (pi_features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (vf_features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (mlp_extractor): MlpExtractor(
#     (policy_net): Sequential(
#       (0): Linear(in_features=8, out_features=256, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): Tanh()
#     )
#     (value_net): Sequential(
#       (0): Linear(in_features=8, out_features=256, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): Tanh()
#     )
#   )
#   (action_net): Linear(in_features=256, out_features=4, bias=True)
#   (value_net): Linear(in_features=256, out_features=1, bias=True)
# )
#
# Total parameters   : 137,477
# Parallel envs      : 16
# Steps per rollout  : 16,384
# Total updates      : ~122

# %%
# ── Train ────────────────────────────────────────────────────────────────────
from stable_baselines3.common.callbacks import CallbackList

print(f'=== PPO (SB3 Improved) — LunarLander-v2 ===')
print(f'Parallel envs    : {NUM_ENVS}')
print(f'Total timesteps  : {TOTAL_TIMESTEPS:,}')
print(f'LR schedule      : {LEARNING_RATE:.0e} -> {LEARNING_RATE_END:.0e}')
print(f'Entropy coef     : {ENTROPY_COEF}\n')

episode_callback = EpisodeLogger()
lr_callback      = LRSchedulerCallback(
    initial_lr      = LEARNING_RATE,
    final_lr        = LEARNING_RATE_END,
    total_timesteps = TOTAL_TIMESTEPS,
)

model.learn(
    total_timesteps = TOTAL_TIMESTEPS,
    callback        = CallbackList([episode_callback, lr_callback]),
    progress_bar    = False,
)

# alias for rest of notebook
callback      = episode_callback
train_rewards = callback.rewards_history
train_steps   = callback.steps_history
train_losses  = callback.loss_history

print(f'\nTraining complete.')
print(f'Episodes completed : {len(train_rewards)}')
if callback.solved_at:
    print(f'Solved at episode  : {callback.solved_at}')
else:
    rm = np.mean(list(callback.rolling)) if callback.rolling else float('nan')
    print(f'Final rolling mean : {rm:.2f} (threshold {SOLVE_REWARD})')
# Out:
# === PPO (SB3 Improved) — LunarLander-v2 ===
# Parallel envs    : 16
# Total timesteps  : 2,000,000
# LR schedule      : 1e-04 -> 1e-05
# Entropy coef     : 0.02
#
# Ep   50 | steps  102 | reward  -384.75 | rolling100 -188.93
# Ep  100 | steps   88 | reward   -95.27 | rolling100 -188.70
# Ep  150 | steps  112 | reward   -85.08 | rolling100 -182.52
# Ep  200 | steps  107 | reward  -166.81 | rolling100 -181.54
# Ep  250 | steps   86 | reward  -425.93 | rolling100 -192.70
# Ep  300 | steps   99 | reward  -243.81 | rolling100 -187.72
# Ep  350 | steps   77 | reward  -109.15 | rolling100 -169.74
# Ep  400 | steps  115 | reward   -49.93 | rolling100 -151.27
# Ep  450 | steps  106 | reward  -269.03 | rolling100 -156.22
# Ep  500 | steps  100 | reward   -96.84 | rolling100 -163.20
# Ep  550 | steps  112 | reward  -150.85 | rolling100 -148.81
# Ep  600 | steps   87 | reward  -178.47 | rolling100 -136.81
# Ep  650 | steps  135 | reward  -133.73 | rolling100 -135.47
# Ep  700 | steps  150 | reward  -206.05 | rolling100 -135.05
# Ep  750 | steps   82 | reward  -101.10 | rolling100 -126.93
# Ep  800 | steps  103 | reward  -128.27 | rolling100 -133.68
# Ep  850 | steps   68 | reward   -28.25 | rolling100 -126.09
# Ep  900 | steps  163 | reward   -31.93 | rolling100 -112.07
# Ep  950 | steps  128 | reward   -88.29 | rolling100 -135.02
# Ep 1000 | steps  108 | reward  -100.43 | rolling100 -128.69
# Ep 1050 | steps  166 | reward   -53.33 | rolling100 -111.59
# Ep 1100 | steps  148 | reward  -177.48 | rolling100 -132.56
# Ep 1150 | steps  147 | reward  -205.55 | rolling100 -138.38
# Ep 1200 | steps  125 | reward  -223.67 | rolling100 -129.76
# Ep 1250 | steps  140 | reward  -157.13 | rolling100 -109.14
# Ep 1300 | steps   95 | reward  -150.13 | rolling100  -98.34
# Ep 1350 | steps  207 | reward  -106.84 | rolling100  -94.08
# Ep 1400 | steps  148 | reward   -34.11 | rolling100  -87.32
# Ep 1450 | steps  219 | reward   -23.15 | rolling100 -105.07
# Ep 1500 | steps  176 | reward   -62.69 | rolling100 -123.46
# Ep 1550 | steps  139 | reward    -0.93 | rolling100  -96.83
# Ep 1600 | steps  160 | reward  -169.01 | rolling100  -72.28
# Ep 1650 | steps  152 | reward    25.01 | rolling100  -71.48
# Ep 1700 | steps  574 | reward  -189.40 | rolling100  -62.86
# Ep 1750 | steps  208 | reward  -207.02 | rolling100  -56.14
# Ep 1800 | steps  190 | reward   -16.59 | rolling100  -48.71
# Ep 1850 | steps  159 | reward  -179.29 | rolling100  -51.70
# Ep 1900 | steps  229 | reward   -67.91 | rolling100  -47.57
# Ep 1950 | steps 1000 | reward    64.11 | rolling100  -33.82
# Ep 2000 | steps  365 | reward  -189.68 | rolling100  -49.39
# Ep 2050 | steps 1000 | reward    25.49 | rolling100  -59.91
# Ep 2100 | steps  413 | reward  -131.10 | rolling100  -43.38
# Ep 2150 | steps 1000 | reward    76.11 | rolling100  -14.28
# Ep 2200 | steps 1000 | reward    47.11 | rolling100    3.02
# Ep 2250 | steps 1000 | reward    48.39 | rolling100   -4.91
# Ep 2300 | steps  823 | reward  -180.17 | rolling100   -3.94
# Ep 2350 | steps 1000 | reward    18.22 | rolling100   -9.64
# Ep 2400 | steps 1000 | reward    65.92 | rolling100    7.09
# Ep 2450 | steps 1000 | reward    20.74 | rolling100   47.83
# Ep 2500 | steps 1000 | reward    73.76 | rolling100   79.18
# Ep 2550 | steps  385 | reward   -11.32 | rolling100   86.17
# Ep 2600 | steps  334 | reward   -41.75 | rolling100   80.43
# Ep 2650 | steps 1000 | reward   122.93 | rolling100   92.94
# Ep 2700 | steps 1000 | reward   117.30 | rolling100   97.98
# Ep 2750 | steps 1000 | reward   109.39 | rolling100   86.63
# Ep 2800 | steps  328 | reward   -52.72 | rolling100   92.71
# Ep 2850 | steps 1000 | reward   117.15 | rolling100  111.57
# Ep 2900 | steps 1000 | reward   107.67 | rolling100  106.84
# Ep 2950 | steps 1000 | reward   124.96 | rolling100   95.51
# Ep 3000 | steps 1000 | reward    85.24 | rolling100   95.88
# Ep 3050 | steps 1000 | reward    94.85 | rolling100   97.14
# Ep 3100 | steps 1000 | reward   136.02 | rolling100   88.92
# Ep 3150 | steps 1000 | reward   104.18 | rolling100   86.44
# Ep 3200 | steps  342 | reward   -26.13 | rolling100   97.25
# Ep 3250 | steps  527 | reward   185.07 | rolling100  107.53
# Ep 3300 | steps  302 | reward   -44.36 | rolling100  108.72
# Ep 3350 | steps 1000 | reward    95.94 | rolling100   94.20
# Ep 3400 | steps  784 | reward    55.73 | rolling100   70.56
# Ep 3450 | steps  551 | reward   167.55 | rolling100   68.18
# Ep 3500 | steps 1000 | reward    74.18 | rolling100   83.92
# Ep 3550 | steps 1000 | reward   -43.60 | rolling100   97.14
# Ep 3600 | steps 1000 | reward    89.67 | rolling100  106.27
# Ep 3650 | steps 1000 | reward   128.72 | rolling100  113.75
# Ep 3700 | steps  850 | reward  -156.72 | rolling100  111.60
# Ep 3750 | steps 1000 | reward   102.32 | rolling100  100.57
# Ep 3800 | steps  437 | reward   183.26 | rolling100   98.60
# Ep 3850 | steps 1000 | reward   106.62 | rolling100  104.29
# Ep 3900 | steps  585 | reward  -141.59 | rolling100   98.95
# Ep 3950 | steps  395 | reward   153.52 | rolling100   99.79
# Ep 4000 | steps 1000 | reward    98.84 | rolling100  112.24
# Ep 4050 | steps 1000 | reward   145.35 | rolling100  118.45
# Ep 4100 | steps 1000 | reward   112.56 | rolling100  110.89
# Ep 4150 | steps  461 | reward   151.12 | rolling100  101.08
# Ep 4200 | steps  202 | reward     5.37 | rolling100  111.48
# Ep 4250 | steps  198 | reward   -19.66 | rolling100  115.55
# Ep 4300 | steps 1000 | reward   125.43 | rolling100  114.30
# Ep 4350 | steps  306 | reward   -44.02 | rolling100  116.74
# Ep 4400 | steps  322 | reward   222.19 | rolling100  108.08
# Ep 4450 | steps  290 | reward   212.08 | rolling100  108.62
#
# Training complete.
# Episodes completed : 4483
# Final rolling mean : 109.56 (threshold 200)

# %%
# ── Save model ───────────────────────────────────────────────────────────────
model.save('ppo_v2_model')
print('Model saved to ppo_v2_model.zip')
# To reload: model = PPO.load('ppo_sb3_lunarlander')
# Out:
# Model saved to ppo_v2_model.zip

# %%
# ── Plot training curves — identical 2x2 layout to hand-written PPO ──────────
rewards_arr = np.array(train_rewards)
episodes    = np.arange(1, len(rewards_arr) + 1)

def rolling_mean(x, w=100):
    return np.convolve(x, np.ones(w) / w, mode='valid')

fig, axes = plt.subplots(2, 2, figsize=(16, 10))
fig.suptitle('PPO (Stable-Baselines3, Improved) — LunarLander-v2 Training',
             fontsize=15, fontweight='bold', y=1.01)

# ── 1. Reward per episode + rolling mean
ax = axes[0, 0]
ax.plot(episodes, rewards_arr, alpha=0.2, color='#378ADD', linewidth=0.6, label='Per-episode')
if len(rewards_arr) >= 100:
    rm = rolling_mean(rewards_arr, 100)
    ax.plot(np.arange(100, len(rewards_arr) + 1), rm,
            color='#185FA5', linewidth=2, label='Rolling mean (100)')
ax.axhline(SOLVE_REWARD, color='#1D9E75', linestyle='--', linewidth=1.5,
           label=f'Solve ({SOLVE_REWARD})')
ax.set_title('Reward per episode', fontweight='bold')
ax.set_xlabel('Episode'); ax.set_ylabel('Total reward')
ax.legend(fontsize=9); ax.grid(True, alpha=0.3)

# ── 2. Steps per episode
ax = axes[0, 1]
ax.plot(episodes, train_steps, alpha=0.25, color='#7F77DD', linewidth=0.6)
if len(train_steps) >= 100:
    ax.plot(np.arange(100, len(train_steps) + 1),
            rolling_mean(np.array(train_steps, dtype=float), 100),
            color='#534AB7', linewidth=2, label='Rolling mean (100)')
ax.set_title('Steps per episode', fontweight='bold')
ax.set_xlabel('Episode'); ax.set_ylabel('Steps')
ax.legend(fontsize=9); ax.grid(True, alpha=0.3)

# ── 3. Actor & Critic losses (from SB3 logger)
ax = axes[1, 0]
if train_losses:
    updates  = np.arange(1, len(train_losses) + 1)
    actor_l  = [l['actor']  for l in train_losses]
    critic_l = [l['critic'] for l in train_losses]
    ax.plot(updates, actor_l,  label='Actor loss',  color='#D85A30', linewidth=1.5)
    ax.plot(updates, critic_l, label='Critic loss', color='#BA7517', linewidth=1.5)
ax.set_title('Actor & Critic losses (per update)', fontweight='bold')
ax.set_xlabel('Update step'); ax.set_ylabel('Loss')
ax.legend(fontsize=9); ax.grid(True, alpha=0.3)

# ── 4. Policy entropy
ax = axes[1, 1]
if train_losses:
    entropy_l = [-l['entropy'] for l in train_losses]
    ax.plot(updates, entropy_l, color='#1D9E75', linewidth=1.5)
ax.set_title('Policy entropy (per update)', fontweight='bold')
ax.set_xlabel('Update step'); ax.set_ylabel('Entropy')
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('ppo_v2_training_curves.png', dpi=150, bbox_inches='tight')
plt.show()
print('Curves saved to ppo_sb3_training_curves.png')
# Out:
# Curves saved to ppo_sb3_training_curves.png

# %%
# ── Summary statistics — identical format to hand-written PPO ────────────────
r = np.array(train_rewards)
print('=== Training Summary ===')
print(f'Episodes trained   : {len(r)}')
print(f'Mean reward        : {r.mean():.2f}')
print(f'Std reward         : {r.std():.2f}')
print(f'Best episode       : {r.max():.2f}')
print(f'Worst episode      : {r.min():.2f}')
if len(r) >= SOLVE_WINDOW:
    final_mean = r[-SOLVE_WINDOW:].mean()
    status = 'SOLVED' if final_mean >= SOLVE_REWARD else 'not yet solved'
    print(f'Final {SOLVE_WINDOW}-ep mean   : {final_mean:.2f} ({status})')
# Out:
# === Training Summary ===
# Episodes trained   : 4483
# Mean reward        : -7.55
# Std reward         : 139.94
# Best episode       : 278.33
# Worst episode      : -511.20
# Final 100-ep mean   : 109.56 (not yet solved)

# %%
# ── Record video — same tag/folder convention as hand-written PPO ────────────
def record_video(model, folder='./videos/ppo_v2', tag='ppo-sb3-agent', n_steps=MAX_STEPS):
    """
    Record one greedy episode using the trained SB3 model.
    Uses the same folder/tag convention as the hand-written PPO notebook.
    """
    env = gym.make(ENV_NAME, render_mode='rgb_array')
    env = gym.wrappers.RecordVideo(
        env, folder,
        episode_trigger=lambda e: True,
        name_prefix=tag
    )
    obs, _ = env.reset(seed=0)
    total_reward, steps = 0, 0
    for _ in range(n_steps):
        # SB3 predict() returns (action, state); deterministic=True = greedy
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, _ = env.step(action)
        total_reward += reward
        steps += 1
        if terminated or truncated:
            break
    env.close()
    print(f'Recorded: {steps} steps, reward {total_reward:.2f}')
    files = sorted(glob.glob(f'{folder}/{tag}*.mp4'))
    if files:
        display(Video(files[-1], embed=True, width=600))

print('Recording video of trained SB3 PPO agent...')
record_video(model)
# Out:
# Recording video of trained SB3 PPO agent...
# Moviepy - Building video e:\University 5B\CS AI\videos\ppo_v2\ppo-sb3-agent-episode-0.mp4.
# Moviepy - Writing video e:\University 5B\CS AI\videos\ppo_v2\ppo-sb3-agent-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready e:\University 5B\CS AI\videos\ppo_v2\ppo-sb3-agent-episode-0.mp4
# Recorded: 237 steps, reward -16.62
# <video controls  width="600" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# ── Evaluation — uses SB3 evaluate_policy + mirrors hand-written format ──────
print('=== Evaluation (20 episodes, greedy) ===')

eval_env = gym.make(ENV_NAME)

# SB3 built-in evaluator
mean_reward, std_reward = evaluate_policy(
    model, eval_env,
    n_eval_episodes=20,
    deterministic=True,
    return_episode_rewards=False
)
eval_env.close()

# Per-episode breakdown — mirrors hand-written PPO eval output
eval_rewards, eval_steps = [], []
eval_env2 = gym.make(ENV_NAME)
for ep in range(20):
    obs, _ = eval_env2.reset(seed=ep)
    total, steps = 0, 0
    for _ in range(MAX_STEPS):
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, _ = eval_env2.step(action)
        total += reward; steps += 1
        if terminated or truncated:
            break
    eval_rewards.append(total)
    eval_steps.append(steps)
    print(f'Eval ep {ep+1:3d}: {steps:4d} steps, reward {total:8.2f}')
eval_env2.close()

print(f'\nEval mean (SB3): {mean_reward:.2f} +/- {std_reward:.2f}')
print(f'Eval mean (manual): {np.mean(eval_rewards):.2f} +/- {np.std(eval_rewards):.2f}')
# Out:
# === Evaluation (20 episodes, greedy) ===
# c:\Users\ninaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval ep   1:  237 steps, reward   -16.62
# Eval ep   2:  844 steps, reward   179.01
# Eval ep   3: 1000 steps, reward    28.89
# Eval ep   4:  503 steps, reward   187.51
# Eval ep   5:  483 steps, reward   198.73
# Eval ep   6:  832 steps, reward   149.19
# Eval ep   7: 1000 steps, reward    78.26
# Eval ep   8:  469 steps, reward   181.64
# Eval ep   9:  629 steps, reward   178.50
# Eval ep  10:  962 steps, reward   167.65
# Eval ep  11:  524 steps, reward   160.69
# Eval ep  12:  397 steps, reward   199.49
# Eval ep  13:  630 steps, reward   180.18
# Eval ep  14:  376 steps, reward   194.24
# Eval ep  15:  490 steps, reward   181.47
# Eval ep  16:  598 steps, reward   182.24
# Eval ep  17:  800 steps, reward   144.90
# Eval ep  18:  842 steps, reward   196.66
# Eval ep  19:  499 steps, reward   166.55
# Eval ep  20: 1000 steps, reward    50.44
#
# Eval mean (SB3): 99.97 +/- 88.35
# Eval mean (manual): 149.48 +/- 60.90
